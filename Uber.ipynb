# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt 
import seaborn as sns
from sqlalchemy import create_engine

# %%
df = pd.read_csv(r"C:\Users\dell\Downloads\archive\ncr_ride_bookings.csv") 
df.head(20)
# Out:
#           Date      Time    Booking ID         Booking Status   Customer ID  \
# 0   2024-03-23  12:29:38  "CNR5884300"        No Driver Found  "CID1982111"
# 1   2024-11-29  18:01:39  "CNR1326809"             Incomplete  "CID4604802"
# 2   2024-08-23  08:56:10  "CNR8494506"              Completed  "CID9202816"
# 3   2024-10-21  17:17:25  "CNR8906825"              Completed  "CID2610914"
# 4   2024-09-16  22:08:00  "CNR1950162"              Completed  "CID9933542"
# 5   2024-02-06  09:44:56  "CNR4096693"              Completed  "CID4670564"
# 6   2024-06-17  15:45:58  "CNR2002539"              Completed  "CID6800553"
# 7   2024-03-19  17:37:37  "CNR6568000"              Completed  "CID8610436"
# 8   2024-09-14  12:49:09  "CNR4510807"        No Driver Found  "CID7873618"
# 9   2024-12-16  19:06:48  "CNR7721892"             Incomplete  "CID5214275"
# 10  2024-06-14  16:24:12  "CNR9070334"              Completed  "CID6680340"
# ...

# %%
df.tail(20)
# Out:
#               Date      Time    Booking ID       Booking Status   Customer ID  \
# 149980  2024-12-10  15:31:45  "CNR6231822"      No Driver Found  "CID6232718"
# 149981  2024-12-10  09:46:40  "CNR9611749"            Completed  "CID1686695"
# 149982  2024-11-13  06:51:19  "CNR4448255"      No Driver Found  "CID9138957"
# 149983  2024-03-23  20:33:36  "CNR1937316"            Completed  "CID7955264"
# 149984  2024-01-14  15:42:15  "CNR2761999"           Incomplete  "CID3743304"
# 149985  2024-02-26  16:45:21  "CNR2991975"            Completed  "CID2480001"
# 149986  2024-03-15  17:49:46  "CNR5247039"            Completed  "CID6218492"
# 149987  2024-02-06  19:51:00  "CNR1535042"            Completed  "CID8787495"
# 149988  2024-08-17  10:43:13  "CNR5410567"            Completed  "CID6192221"
# 149989  2024-07-22  10:04:18  "CNR2531850"            Completed  "CID7189367"
# 149990  2024-09-26  12:31:22  "CNR3212810"  Cancelled by Driver  "CID6199171"
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150000 entries, 0 to 149999
# Data columns (total 21 columns):
#  #   Column                             Non-Null Count   Dtype
# ---  ------                             --------------   -----
#  0   Date                               150000 non-null  object
#  1   Time                               150000 non-null  object
#  2   Booking ID                         150000 non-null  object
#  3   Booking Status                     150000 non-null  object
#  4   Customer ID                        150000 non-null  object
#  5   Vehicle Type                       150000 non-null  object
#  6   Pickup Location                    150000 non-null  object
#  7   Drop Location                      150000 non-null  object
#  8   Avg VTAT                           139500 non-null  float64
#  9   Avg CTAT                           102000 non-null  float64
#  10  Cancelled Rides by Customer        10500 non-null   float64
# ...

# %%
df.isnull().sum()
# Out:
# Date                                      0
# Time                                      0
# Booking ID                                0
# Booking Status                            0
# Customer ID                               0
# Vehicle Type                              0
# Pickup Location                           0
# Drop Location                             0
# Avg VTAT                              10500
# Avg CTAT                              48000
# Cancelled Rides by Customer          139500
# Reason for cancelling by Customer    139500
# Cancelled Rides by Driver            123000
# Driver Cancellation Reason           123000
# Incomplete Rides                     141000
# Incomplete Rides Reason              141000
# Booking Value                         48000
# Ride Distance                         48000
# Driver Ratings                        57000
# Customer Rating                       57000
# Payment Method                        48000
# dtype: int64

# %%
48000+57000+57000+48000+48000+141000+141000+123000+123000+139500+139500+48000+10500
# Out:
# 1123500

# %%
10500/150000
# Out:
# 0.07

# %%
48000/150000
# Out:
# 0.32

# %%
df.columns=df.columns.str.lower() 
df.columns=df.columns.str.replace(' ','_')

# %%
obj_columns=df.dtypes[df.dtypes=="object"].index

# %%
obj_columns
# Out:
# Index(['date', 'time', 'booking_id', 'booking_status', 'customer_id',
#        'vehicle_type', 'pickup_location', 'drop_location',
#        'reason_for_cancelling_by_customer', 'driver_cancellation_reason',
#        'incomplete_rides_reason', 'payment_method'],
#       dtype='object')

# %%
num_columns=df.select_dtypes(include="number").columns

# %%
num_columns
# Out:
# Index(['avg_vtat', 'avg_ctat', 'cancelled_rides_by_customer',
#        'cancelled_rides_by_driver', 'incomplete_rides', 'booking_value',
#        'ride_distance', 'driver_ratings', 'customer_rating'],
#       dtype='object')

# %%
df.columns
# Out:
# Index(['date', 'time', 'booking_id', 'booking_status', 'customer_id',
#        'vehicle_type', 'pickup_location', 'drop_location', 'avg_vtat',
#        'avg_ctat', 'cancelled_rides_by_customer',
#        'reason_for_cancelling_by_customer', 'cancelled_rides_by_driver',
#        'driver_cancellation_reason', 'incomplete_rides',
#        'incomplete_rides_reason', 'booking_value', 'ride_distance',
#        'driver_ratings', 'customer_rating', 'payment_method'],
#       dtype='object')

# %%
df['booking_id'].value_counts()
# Out:
# booking_id
# "CNR3648267"    3
# "CNR9603232"    3
# "CNR7642097"    3
# "CNR7585544"    3
# "CNR7908610"    3
#                ..
# "CNR3614535"    1
# "CNR4499383"    1
# "CNR9834201"    1
# "CNR8779845"    1
# "CNR6568000"    1
# Name: count, Length: 148767, dtype: int64

# %%
df["customer_id"].value_counts()
# Out:
# customer_id
# "CID6715450"    3
# "CID4523979"    3
# "CID6468528"    3
# "CID7828101"    3
# "CID8727691"    3
#                ..
# "CID5432215"    1
# "CID2581698"    1
# "CID8682675"    1
# "CID1060329"    1
# "CID9046501"    1
# Name: count, Length: 148788, dtype: int64

# %%
df["vehicle_type"].unique()
# Out:
# array(['eBike', 'Go Sedan', 'Auto', 'Premier Sedan', 'Bike', 'Go Mini',
#        'Uber XL'], dtype=object)

# %%
df["vehicle_type"].value_counts()
# Out:
# vehicle_type
# Auto             37419
# Go Mini          29806
# Go Sedan         27141
# Bike             22517
# Premier Sedan    18111
# eBike            10557
# Uber XL           4449
# Name: count, dtype: int64

# %%
df["vehicle_type"].isnull().sum()
# Out:
# np.int64(0)

# %%
df['booking_status'].unique()
# Out:
# array(['No Driver Found', 'Incomplete', 'Completed',
#        'Cancelled by Driver', 'Cancelled by Customer'], dtype=object)

# %%
df['booking_status'].value_counts()
# Out:
# booking_status
# Completed                93000
# Cancelled by Driver      27000
# No Driver Found          10500
# Cancelled by Customer    10500
# Incomplete                9000
# Name: count, dtype: int64

# %%
df['booking_status'].isnull().sum()
# Out:
# np.int64(0)

# %%
df['pickup_location'].value_counts()
# Out:
# pickup_location
# Khandsa             949
# Barakhamba Road     946
# Saket               931
# Badarpur            921
# Pragati Maidan      920
#                    ...
# Mandi House         800
# Noida Sector 18     799
# Laxmi Nagar         797
# Ashok Vihar         796
# Ghitorni Village    790
# Name: count, Length: 176, dtype: int64

# %%
df['drop_location'].value_counts()
# Out:
# drop_location
# Ashram              936
# Basai Dhankot       917
# Lok Kalyan Marg     916
# Narsinghpur         913
# Cyber Hub           912
#                    ...
# MG Road             799
# Bhiwadi             792
# Shivaji Park        786
# Anand Vihar ISBT    784
# Huda City Centre    774
# Name: count, Length: 176, dtype: int64

# %%
completed_avg_median_ctat= df[df["booking_status"]=="completed"]["avg_ctat"].median()
df.loc[df["booking_status"]=="completed","avg_ctat"]=df.loc[df["booking_status"]=="completed","avg_ctat"].fillna("completed_avg_median_ctat")

# %%
completed_avg_median_vtat= df[df["booking_status"]=="completed"]["avg_vtat"].median()
df.loc[df["booking_status"]=="completed","avg_vtat"]=df.loc[df["booking_status"]=="completed","avg_vtat"].fillna("completed_avg_median_vtat")

# %%
df["avg_vtat"].isnull().sum()
# Out:
# np.int64(10500)

# %%
df["avg_ctat"].isnull().sum()
# Out:
# np.int64(48000)

# %%
df["avg_ctat"]=df["avg_ctat"].fillna(0)

# %%
df["avg_vtat"]=df["avg_vtat"].fillna(0)

# %%
df[["avg_ctat","avg_vtat"]].head()
# Out:
#    avg_ctat  avg_vtat
# 0       0.0       0.0
# 1      14.0       4.9
# 2      25.8      13.4
# 3      28.5      13.1
# 4      19.6       5.3

# %%
df["date"]=pd.to_datetime(df["date"]).dt.date

# %%
df["date"].head()
# Out:
# 0    2024-03-23
# 1    2024-11-29
# 2    2024-08-23
# 3    2024-10-21
# 4    2024-09-16
# Name: date, dtype: object

# %%
df["time"]=pd.to_datetime(df["time"])
# Out:
# C:\Users\dell\AppData\Local\Temp\ipykernel_18580\329128545.py:1: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df["time"]=pd.to_datetime(df["time"])

# %%
df["hour"]=pd.to_datetime(df["time"]).dt.hour

# %%
df.drop(columns=["time"],inplace=True)

# %%
df.columns
# Out:
# Index(['date', 'booking_id', 'booking_status', 'customer_id', 'vehicle_type',
#        'pickup_location', 'drop_location', 'avg_vtat', 'avg_ctat',
#        'cancelled_rides_by_customer', 'reason_for_cancelling_by_customer',
#        'cancelled_rides_by_driver', 'driver_cancellation_reason',
#        'incomplete_rides', 'incomplete_rides_reason', 'booking_value',
#        'ride_distance', 'driver_ratings', 'customer_rating', 'payment_method',
#        'hour'],
#       dtype='object')

# %%
df["day"]=pd.to_datetime(df["date"]).dt.day

# %%
df["year"]=pd.to_datetime(df["date"]).dt.year

# %%
df["month"]=pd.to_datetime(df["date"]).dt.month

# %%
df.columns
# Out:
# Index(['date', 'booking_id', 'booking_status', 'customer_id', 'vehicle_type',
#        'pickup_location', 'drop_location', 'avg_vtat', 'avg_ctat',
#        'cancelled_rides_by_customer', 'reason_for_cancelling_by_customer',
#        'cancelled_rides_by_driver', 'driver_cancellation_reason',
#        'incomplete_rides', 'incomplete_rides_reason', 'booking_value',
#        'ride_distance', 'driver_ratings', 'customer_rating', 'payment_method',
#        'hour', 'day', 'year', 'month'],
#       dtype='object')

# %%
df['cancelled_rides_by_customer'].value_counts()
# Out:
# cancelled_rides_by_customer
# 1.0    10500
# Name: count, dtype: int64

# %%
df['cancelled_rides_by_customer']=df["cancelled_rides_by_customer"].fillna(0)

# %%
df['cancelled_rides_by_customer'].value_counts()
# Out:
# cancelled_rides_by_customer
# 0.0    139500
# 1.0     10500
# Name: count, dtype: int64

# %%
df['reason_for_cancelling_by_customer'].value_counts()
# Out:
# reason_for_cancelling_by_customer
# Wrong Address                                   2362
# Change of plans                                 2353
# Driver is not moving towards pickup location    2335
# Driver asked to cancel                          2295
# AC is not working                               1155
# Name: count, dtype: int64

# %%
df['reason_for_cancelling_by_customer']=df['reason_for_cancelling_by_customer'].fillna("Not by customer")

# %%
df['reason_for_cancelling_by_customer'].value_counts()
# Out:
# reason_for_cancelling_by_customer
# Not by customer                                 139500
# Wrong Address                                     2362
# Change of plans                                   2353
# Driver is not moving towards pickup location      2335
# Driver asked to cancel                            2295
# AC is not working                                 1155
# Name: count, dtype: int64

# %%
df['cancelled_rides_by_driver'].value_counts()
# Out:
# cancelled_rides_by_driver
# 1.0    27000
# Name: count, dtype: int64

# %%
df['cancelled_rides_by_driver']=df['cancelled_rides_by_driver'].fillna(0)

# %%
df['cancelled_rides_by_driver'].value_counts()
# Out:
# cancelled_rides_by_driver
# 0.0    123000
# 1.0     27000
# Name: count, dtype: int64

# %%
df["driver_cancellation_reason"].value_counts()
# Out:
# driver_cancellation_reason
# Customer related issue                 6837
# The customer was coughing/sick         6751
# Personal & Car related issues          6726
# More than permitted people in there    6686
# Name: count, dtype: int64

# %%
df['driver_cancellation_reason']=df['driver_cancellation_reason'].fillna("Not cancelled by driver")

# %%
df["driver_cancellation_reason"].value_counts()
# Out:
# driver_cancellation_reason
# Not cancelled by driver                123000
# Customer related issue                   6837
# The customer was coughing/sick           6751
# Personal & Car related issues            6726
# More than permitted people in there      6686
# Name: count, dtype: int64

# %%
df['incomplete_rides'].value_counts()
# Out:
# incomplete_rides
# 1.0    9000
# Name: count, dtype: int64

# %%
df['incomplete_rides'].isnull().sum()
# Out:
# np.int64(141000)

# %%
df['incomplete_rides']=df['incomplete_rides'].fillna(0)

# %%
df['incomplete_rides_reason'].value_counts()
# Out:
# incomplete_rides_reason
# Customer Demand      3040
# Vehicle Breakdown    3012
# Other Issue          2948
# Name: count, dtype: int64

# %%
df['incomplete_rides_reason']=df['incomplete_rides_reason'].fillna('Ride Completed')

# %%
df2=df

# %%
df2["booking_value"].isnull().sum()
# Out:
# np.int64(48000)

# %%
df2["booking_value"]=df2["booking_value"].fillna(0)

# %%
df2["ride_distance"].isnull().sum()
# Out:
# np.int64(48000)

# %%
df2["ride_distance"]=df2["ride_distance"].fillna(0)

# %%
df2['driver_ratings'].isnull().sum()
# Out:
# np.int64(57000)

# %%
df2['driver_ratings']=df2['driver_ratings'].fillna(df2["driver_ratings"].median())

# %%
df2['customer_rating'].isnull().sum()
# Out:
# np.int64(57000)

# %%
df2["customer_rating"]=df2["customer_rating"].fillna(df2["customer_rating"].median())

# %%
df2["cancelled_rides"]=df2["cancelled_rides_by_customer"]+df['cancelled_rides_by_driver']

# %%
df2["cancelled_rides"].value_counts()
# Out:
# cancelled_rides
# 0.0    112500
# 1.0     37500
# Name: count, dtype: int64

# %%
df2["incomplete_rides"].value_counts()
# Out:
# incomplete_rides
# 0.0    141000
# 1.0      9000
# Name: count, dtype: int64

# %%
df2['payment_method'].isnull().sum()
# Out:
# np.int64(48000)

# %%
df2['payment_method']=df2['payment_method'].fillna('Not Applicable')

# %%
valid_completion_rides= (
(df2["cancelled_rides_by_driver"] == 0) & # cancelled by Driver
(df2["cancelled_rides_by_customer"] == 0) & # cancelled by Customer
(df2['avg_vtat'] > 0) & #Driver actually spent time arriving
(df2['ride_distance'] > 0) #Passenger was actually transported
)

# %%
valid_completion_rides.sum()
# Out:
# np.int64(102000)

# %%
df2["payment_method"].isnull().sum()
# Out:
# np.int64(0)

# %%
engine = create_engine('mysql+pymysql://root:Viren%40015@localhost:3306/uber')

# %%
df2.to_sql(name='data',con=engine,if_exists="replace",index=False)
# Out:
# 150000

# %%
df2.to_csv("cleaned_uber_data.csv",index=False)

# %%
df3=pd.read_csv("cleaned_uber_data.csv")

# %%
# Out:
#          date    booking_id   booking_status   customer_id   vehicle_type  \
# 0  2024-03-23  "CNR5884300"  No Driver Found  "CID1982111"          eBike
# 1  2024-11-29  "CNR1326809"       Incomplete  "CID4604802"       Go Sedan
# 2  2024-08-23  "CNR8494506"        Completed  "CID9202816"           Auto
# 3  2024-10-21  "CNR8906825"        Completed  "CID2610914"  Premier Sedan
# 4  2024-09-16  "CNR1950162"        Completed  "CID9933542"           Bike
#
#        pickup_location      drop_location  avg_vtat  avg_ctat  \
# 0          Palam Vihar            Jhilmil       0.0       0.0
# 1        Shastri Nagar  Gurgaon Sector 56       4.9      14.0
# 2              Khandsa      Malviya Nagar      13.4      25.8
# 3  Central Secretariat           Inderlok      13.1      28.5
# 4     Ghitorni Village        Khan Market       5.3      19.6
#
#    cancelled_rides_by_customer  ... booking_value  ride_distance  \
# 0                          0.0  ...           0.0           0.00
# ...
